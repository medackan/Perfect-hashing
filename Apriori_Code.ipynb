# %% [markdown]
# Apriori without hashing

# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori, association_rules
import time

start_time = time.time()

df = pd.read_csv('4and5data.csv', names = ['products'], sep = ',')
data = df['products'].apply(lambda x:x.split(',') )

s=10 #Initialize the support value according to your demand.
init = []
for i in data:
    for q in i:
        if(q not in init):
            init.append(q)
init = sorted(init)
re=[]
for i in range(1,len(init)+1):
    re.append(i)
    
    
item_indexx=dict(zip(init,re))

V=[]
for k,v in item_indexx.items():
    V.append(k)
    
ll = []
for i in data:
    ak = [item_indexx[j] if j in V else j for j in i]
    ll.append(ak)
    
G = []
for i in ll:
    for q in i:
        if(q not in G):
            G.append(q)
            
from collections import Counter
c = Counter()
my_dicttt={}
for i in G: #printing the frequency of items in dataset
    for d in ll:
        if(i in d):
            c[i]+=1
print("C1:")
for i in c:
    print(str([i])+": "+str(c[i]))
    
    
    
l = Counter()  #pruning 
for i in c:
    if(c[i] >= s):
        l[frozenset([i])]+=c[i]
print("L1:")
for i in l:
    new_keyy =str(list(i))
    new_valuee =l[i]
    my_dicttt[new_keyy] = new_valuee
    print(str(list(i))+": "+str(l[i]))


neww = pd.DataFrame.from_dict(my_dicttt,orient ='index')
neww.rename(columns={ neww.columns[0]: "supp_count" }, inplace = True)
neww.reset_index(level=0, inplace=True)
neww.rename(columns = {'index':'item_sets'}, inplace = True)

D=[]
for i in neww['item_sets']:
    a=eval(i)
    D.append(a[0])
neww['item_sets'] = D

my_dict={}
pl = l
pos = 1
for count in range (2,3): #change the value of range to find which itemset to find out. here 2 itemset is found
    nc = set()
    temp = list(l)
    for i in range(0,len(temp)):
        for j in range(i+1,len(temp)):
            t = temp[i].union(temp[j])
            if(len(t) == count):
                nc.add(temp[i].union(temp[j]))
    nc = list(nc)
    c = Counter()
    for i in nc:
        c[i] = 0
        for q in ll:
            temp = set(q)
            if(i.issubset(temp)):
                c[i]+=1
                #c[i]+=1/len(ll)
    print("C"+str(count)+":")
    for i in c:
        print(str(list(i))+": "+str(c[i]))
    print()
    l = Counter()
    for i in c:
        if(c[i] >= s):
            l[i]+=c[i]
            #lift=l/
    print("L"+str(count)+":")
    for i in l:
        new_key = str(list(i))
        new_value = str(l[i])
        my_dict[new_key] = new_value
        #aaaaa=1
        #lift=1
        #for g in eval(new_key):
            #aaaaa*=neww.loc[neww['item_sets'] == g, 'supp_count'].iloc[0]
        #for s in eval(i):
        #ddd=df1.loc[df1['item_sets'] == s, 'supp_count'].iloc[0]
        #aaaaa*=int(ddd)
        
        print(str(list(i))+": "+str(l[i]))
        #print("lift value of",list(i),":",l[i]/aaaaa)
    if(len(l) == 0):
        break
    pl = l
    pos = count
print("Result: ")
print("L"+str(pos)+":")
for i in pl:
    print(str(list(i))+": "+str(pl[i]))
print()

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# C1:
# [17]: 2114
# [19]: 986
# [10]: 2048
# [16]: 1443
# [15]: 3029
# [11]: 2084
# [4]: 2039
# [13]: 2549
# [20]: 1740
# [6]: 2749
# [1]: 2775
# [9]: 1239
# [14]: 2740
# [12]: 3170
# [2]: 3170
# [3]: 2204
# [5]: 2092
# [8]: 2198
# [7]: 1082
# [18]: 1049
# L1:
# [17]: 2114
# [19]: 986
# [10]: 2048
# [16]: 1443
# [15]: 3029
# [11]: 2084
# [4]: 2039
# [13]: 2549
# [20]: 1740
# [6]: 2749
# [1]: 2775
# [9]: 1239
# [14]: 2740
# [12]: 3170
# [2]: 3170
# [3]: 2204
# [5]: 2092
# [8]: 2198
# [7]: 1082
# [18]: 1049
# C2:
# [8, 2]: 1105
# [2, 3]: 1120
# [19, 14]: 312
# [10, 13]: 516
# [8, 7]: 569
# [14, 7]: 0
# [5, 13]: 704
# [2, 11]: 501
# [1, 10]: 318
# [9, 2]: 321
# [17, 6]: 325
# [3, 4]: 503
# [1, 14]: 1788
# [16, 17]: 649
# [9, 13]: 243
# [16, 12]: 563
# [16, 15]: 605
# [2, 4]: 520
# [16, 13]: 514
# [1, 19]: 321
# [9, 14]: 585
# [3, 11]: 547
# [9, 15]: 258
# [11, 14]: 257
# [9, 12]: 298
# [4, 7]: 527
# [18, 20]: 517
# [10, 20]: 545
# [6, 7]: 0
# [12, 5]: 1057
# [5, 15]: 750
# [2, 19]: 342
# ...

# %% [markdown]
# Apriori with Hasing Function

# %%
#
itemf=int(input(" item to find:"))
s=10 #Initialize the support value according to your demand.
import pandas as pd
import numpy as np
import time
from mlxtend.frequent_patterns import apriori, association_rules

start_time = time.time()

df = pd.read_csv('4and5data.csv', names = ['products'], sep = ',')
data = df['products'].apply(lambda x:x.split(',') )

init = []
for i in data:
    for q in i:
        if(q not in init):
            init.append(q)
re=[]
for i in range(1,len(init)+1):
    re.append(i)
item_indexx=dict(zip(init,re))
V=[]
for k,v in item_indexx.items():
    V.append(k)
ll = []
for i in data:
    ak = [item_indexx[j] if j in V else j for j in i]
    ll.append(ak)

  



G = []
for i in ll:
    for q in i:
        if(q not in G):
            G.append(q)
from collections import Counter
c = Counter()
my_dicttt={}
for i in G: #printing the frequency of items in dataset
    for d in ll:
        if(i in d):
            c[i]+=1
#print("C1:")
#for i in c:
#    print(str([i])+": "+str(c[i]))
#print()
l = Counter()  #pruning 
for i in c:
    if(c[i] >= s):
        l[frozenset([i])]+=c[i]
for i in l:
    new_keyy =str(list(i))
    new_valuee =l[i]
    my_dicttt[new_keyy] = new_valuee


neww = pd.DataFrame.from_dict(my_dicttt,orient ='index')
neww.rename(columns={ neww.columns[0]: "supp_count" }, inplace = True)
neww.reset_index(level=0, inplace=True)
neww.rename(columns = {'index':'item_sets'}, inplace = True)
D=[]
for i in neww['item_sets']:
    a=eval(i)
    D.append(a[0])
neww['item_sets'] = D

import itertools
b=list(itertools.combinations(neww['item_sets'], itemf))

def c2(n):
    return n*(n-1)/2
def h3(i,j,k,r):
    c=0
    for m in range (r-1, r-i,-1):
        c=c+c2(m)
    return c+h2(j-i,k-i,r-i)
def c3(n):
    return n*(n-1)*(n-2)/6
def h4(i,j,k,l,r):
    c=0
    for m in range (r-1, r-i,-1):
        c=c+c3(m)
    return c+h3(j-i,k-i,l-i,r-i)
def h2(i,j,r):
    return ((i-1)*(2*r-i)/2)+(j-i)
def c4(n):
    return n*(n-1)*(n-2)*(n-3)/24

def h5(i,j,k,l,o,r):
    c=0
    for m in range (r-1, r-i,-1):
        c=c+c4(m)
    return c+h4(j-i,k-i,l-i,o-i,r-i)


r=len(G)
def hashh(e):
    if len(e)==2:
        h=h2(e[0],e[1],r)
    elif len(e)==3:
        h=h3(e[0],e[1],e[2],r)
    elif len(e)==4:
        h=h4(e[0],e[1],e[2],e[3],r)
    elif len(e)==5:
        h=h5(e[0],e[1],e[2],e[3],e[4],r)
    else:
        h=0
    return h

my_dict={}
for e in b:
    new_key = hashh(e) 
    new_value = tuple(e)
    my_dict[new_key] = new_value

A=[]
for i in my_dict.values():
    i=set(i)
    if len(i)==itemf:
        A.append(i)
        
my_dictt = {}
ll_sets = [set(q) for q in ll]  # pre-calculate the sets of ll

# convert A to a tuple of sets to avoid calculating the set of i in each iteration
A_sets = [set(i) for i in A]
for i in A_sets:
    c = 0
    for q_set in ll_sets:
        if i.issubset(q_set):
            c += 1

    new_key = tuple(i)
    new_value = c
    my_dictt[new_key] = new_value

my_dict_filtered = {k: v for k, v in my_dictt.items() if v >= s}


end_time = time.time()
execution_time = end_time - start_time
print(len(my_dict_filtered))#the number of itemset
print("Execution time:", execution_time, "seconds")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-b7ebb706427a> in <cell line: 2>()
#       1 #
# ----> 2 itemf=int(input(" item to find:"))
#       3 s=10 #Initialize the support value according to your demand.
#       4 import pandas as pd
#       5 import numpy as np
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
# ...
